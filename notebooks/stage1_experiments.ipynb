# %% [markdown]
# # Stage 1 Experiments — Stock Research Chain
#
# Use this notebook to try things out before moving code into `src/chains/stock_research_chain.py`.
#
# This is a safe sandbox — nothing here runs in production.

# %%
# Load environment variables from .env
# This must run first — before any API calls
from dotenv import load_dotenv
load_dotenv()
print('Environment loaded')
